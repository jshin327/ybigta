# %% [markdown]
# <a href="https://colab.research.google.com/github/jshin327/ybigta/blob/master/%ED%81%AC%EB%A1%A4%EB%A7%81_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 크롤링 실습

# %%
# 필요한 라이브러리 다운로드
# 이미 설치되어 있으면 실행하지 않으셔도 됩니다

# !pip3 install requests
# !pip3 install bs4
# !pip3 install selenium
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4) (4.6.3)
# Collecting selenium
#   Downloading selenium-3.141.0-py2.py3-none-any.whl (904 kB)
#      |████████████████████████████████| 904 kB 5.1 MB/s
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.24.3)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %% [markdown]
# ### GET 요청하기

# %%
import requests

url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=%EC%A0%9C%EC%A3%BC%EB%8F%84&oquery=%EC%A0%9C%EC%A3%BC%EB%8F%84+%EC%97%AC%ED%96%89&tqi=htg9ydp0YiRsseJsM%2FNsssssshV-011537'
res = requests.get(url)

print(res) # 응답 객체
res.text # HTML 텍스트
# Out:
# <Response [200]>
# '<!doctype html> <html lang="ko"> <head> <meta charset="utf-8"> <meta name="referrer" content="always">  <meta name="format-detection" content="telephone=no,address=no,email=no"> <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=2.0"> <meta property="og:title" content="제주도 : 네이버 통합검색"/> <meta property="og:image" content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png"> <meta property="og:description" content="\'제주도\'의 네이버 통합검색 결과입니다."> <meta name="description" lang="ko" content="\'제주도\'의 네이버 통합검색 결과입니다."> <title>제주도 : 네이버 통합검색</title> <link rel="shortcut icon" href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico">  <link rel="search" type="application/opensearchdescription+xml" href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" title="Naver" /><link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_210812.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_210812a.css"> <link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css"><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g, \'\'); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError(\'"this" is null or not defined\'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { \'use strict\'; if (!((typeof func === \'Function\' || typeof func === \'function\') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === \'undefined\') d = \'|\' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== \'undefined\') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + e ...

# %% [markdown]
# #### HTTP 상태 코드
#  - 1xx (정보): 요청을 받았으며 프로세스를 계속한다
#  - 2xx (성공): 요청을 성공적으로 받았으며 인식했고 수용하였다
#  - 3xx (리다이렉션): 요청 완료를 위해 추가 작업 조치가 필요하다
#  - 4xx (클라이언트 오류): 요청의 문법이 잘못되었거나 요청을 처리할 수 없다
#  - 5xx (서버 오류): 서버가 명백히 유효한 요청에 대해 충족을 실패했다
#
# [출처: 위키피디아](https://ko.wikipedia.org/wiki/HTTP_%EC%83%81%ED%83%9C_%EC%BD%94%EB%93%9C)

# %%
res.status_code # HTTP 상태 코드
# Out:
# 200

# %% [markdown]
# ## BeautifulSoup

# %%
# 임시 html 텍스트
html = '''
<html>
  <head>
    <title>Example HTML</title>
  </head>
  <body>
    <div id='first' class='Example'>
      <h3 title='Good Content Title'>Contents Title</h3>
      <p>Test contents</p>
    </div>
    <div id='second' class='Example'>
      <p>Text1</p>
      <p>Text2</p>
      <p>Text3</p>
    </div>
  </body>
</html>
'''

# %%
from bs4 import BeautifulSoup

# 첫 번째 인자: 파싱할 객체
# 두 번째 인자: 사용할 parser(구문 분석기)
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# ### find(), find_all()
# 태그 검색
# - find(tag, attributes, recursive, text, keywords)
# - find_all(tag, attributes, recursive, text, limit, keywords)
#
# ### get_text()
# 태그 내 텍스트 반환(부모 태그의 경우 자식 태그의 텍스트를 모두 반환)

# %%
tag = soup.find('h3')
print(tag)
tag.get_text()
# Out:
# <h3 title="Good Content Title">Contents Title</h3>
# 'Contents Title'

# %%
tag = soup.find('p')
print(tag)
tag.get_text()
# Out:
# <p>Test contents</p>
# 'Test contents'

# %%
# find_all은 list 형태로 값 반환
soup.find_all('p')
# Out:
# [<p>Test contents</p>, <p>Text1</p>, <p>Text2</p>, <p>Text3</p>]

# %%
soup.find_all('p')[2].get_text()
# Out:
# 'Text2'

# %%
# 개수 제한
soup.find_all('p', limit=2)
# Out:
# [<p>Test contents</p>, <p>Text1</p>]

# %%
# 여러 태그
soup.find_all({'p', 'h3'})
# Out:
# [<h3 title="Good Content Title">Contents Title</h3>,
#  <p>Test contents</p>,
#  <p>Text1</p>,
#  <p>Text2</p>,
#  <p>Text3</p>]

# %%
# 해당 태그가 여러 개일 경우 첫번째 태그 반환
soup.find('div')
# Out:
# <div class="Example" id="first">
# <h3 title="Good Content Title">Contents Title</h3>
# <p>Test contents</p>
# </div>

# %%
# 특정 속성을 가진 태그 검색
soup.find('div', {'id': 'second'})
# Out:
# <div class="Example" id="second">
# <p>Text1</p>
# <p>Text2</p>
# <p>Text3</p>
# </div>

# %%
# keyword 매개변수 이용
soup.find('div', id='second')
# Out:
# <div class="Example" id="second">
# <p>Text1</p>
# <p>Text2</p>
# <p>Text3</p>
# </div>

# %%
# 속성이 여러 개일 경우
attrs = {
    'id': 'second',
    'class': 'Example'
}
soup.find('div', attrs)
# Out:
# <div class="Example" id="second">
# <p>Text1</p>
# <p>Text2</p>
# <p>Text3</p>
# </div>

# %% [markdown]
# ### 간단한 예제
#
# 네이버 검색 데이터 추출
#
#
# [예제 URL](https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%A0%9C%EC%A3%BC%EB%8F%84)

# %%
url = 'https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=1&ie=utf8&query=%EC%A0%9C%EC%A3%BC%EB%8F%84'
res = requests.get(url)

# 첫번째 인자를 텍스트로 넣어줘야 함
soup = BeautifulSoup(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE doctype html>
#  <html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="제주도 : 네이버 통합검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'제주도'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'제주도'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>제주도 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_210805.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_210805.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_210318.css" rel="stylesheet" type="text/css"/><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { 'use strict'; if (!((typeof func === 'Function' || typeof func === 'function') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; exp ...
# <link as="style" data-chunk="main" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/main-d67f7605.css" rel="preload"/>
# <link as="script" data-chunk="main" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/runtime~main-bundle-835eb794.js" rel="preload"/>
# <link as="script" data-chunk="main" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/main-bundle-d67f7605.js" rel="preload"/>
# <link as="script" data-chunk="components-mainContainer" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/components-mainContainer-bundle-33a0694e.js" rel="preload"/>
# <link as="script" data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/13-bundle-9840ee10.js" rel="preload"/>
# <link as="script" data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/11-bundle-df8350c9.js" rel="preload"/>
# <link as="script" data-chunk="pages-info" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/pages-info-bundle-c92a63f1.js" rel="preload"/>
# <link data-chunk="main" href="https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/main-d67f7605.css" rel="stylesheet"/>
# <div id="nxTsDo"><div class="nx_ts_do as_pc sc_new no-webkit"><style>
#     .nx_ts_do .Header {
#       border-top-color: rgba(103, 132, 118, 0.35);
#       background-color: rgb(232, 236, 234);
#     }
#     .nx_ts_do.as_mo .Header .title > .details .summary,
#     .nx_ts_do.as_pc .Header .info {
#       border-color: rgb(73, 111, 93);
#     }
#     .nx_ts_do.as_mo .Header .title > .details .summary::before,
#     .nx_ts_do.as_pc .Header .info::before {
#       border-color: rgba(73, 111, 93, 0.8);
#     }
#     .nx_ts_do .Header .title > .details {
#     }
#     .nx_ts_do .Header .gnb_list::after {
#       background-image: linear-gradient(to left, rgb(232, 236, 234), rgba(232, 236, 234, 0));
#     }
#     .nx_ts_do .Header .gnb_list .list {
#       color: rgb(73, 111, 93);
#     }
#     .nx_ts_do .Header .gnb_list .list .item[aria-selected="true"] .anchor {
#       background-color: rgb(103, 132, 118);
#     }
#     .nx_ts_do .Header .gnb_list .list .item .anchor::before {
#       background-color: rgba(103, 132, 118, 0.3);
#     }
#     .nx_ts_do .Header .sub_title {
#       color: rgba(73, 111, 93, 0.8);
#     }
#     .nx_ts_do.as_mo .Header.is_fixed .inner {
#       background-color: rgb(232, 236, 234);
#       border-bottom-color: rgba(103, 132, 118, 0.28);
#       box-shadow: 0 0 4px 0 rgba(232, 236, 234, 0.3), 0 2px 3px 0 rgba(0, 0, 0, 0.07);
#     }
#     .nx_ts_do.as_mo .Header.is_fixed_footer .inner {
#       background-color: rgb(232, 236, 234);
#     }
#     .nx_ts_do .do_content {
#       background-image: linear-gradient(to bottom, rgb(232, 236, 234) 128px, rgb(242, 245, 244) 377px);
#     }
#     .nx_ts_do.as_mo .do_content {
#       border-bottom-color: rgba(103, 132, 118, 0.35);
#     }
#     .nx_ts_do .Summary .indent_information,
#     .nx_ts_do .Info .indent_information {
#       border-left-color: rgba(232, 236, 234, 0.9);
#     }
#     .nx_ts_do .Summary .filters .multiple,
#     .nx_ts_do .Summary .filters .button[aria-selected="true"],
#     .nx_ts_do .Reservation .reservation_rooms .types > .button[aria-selected="true"],
#     .nx_ts_do .Guide .filter .Tag[aria-selected='true'] {
#       border-color: rgba(103, 132, 118, 0.5);
#       color: rgb(73, 111, 93);
#       background-color: rgba(103, 132, 118, 0.03);
#     }
#     .nx_ts_do .Summary .filters .multiple::after {
#       border-top-color: rgb(103, 132, 118);
#     }
#     .nx_ts_do .tab_list {
#       color: rgb(73, 111, 93);
#       border-color: rgb(103, 132, 118);
#     }
#     .nx_ts_do.as_pc .Summary .spots .figcaption > .rank {
#       background-color: rgb(73, 111, 93);
#     }
#     .nx_ts_do.as_mo .Summary .spots .figcaption > .rank {
#       background-color: rgba(73, 111, 93, 0.8);
#     }
#     .nx_ts_do .Info .alert {
#       color: rgb(73, 111, 93);
#       background-color: rgba(103, 132, 118, 0.06);
#     }
#     .nx_travelsearch .border {
#       border-bottom-color: rgba(103, 132, 118, 0.28);
#     }
#     .nx_travelsearch .top_box {
#       box-shadow: 0 0 4px 0 rgba(103, 132, 118, 0.3), 0 2px 3px 0 rgba(0, 0, 0, 0.07);
#     }
#     .nx_travelsearch .api_save_group .btn_save .ico_save,
#     .nx_travelsearch .api_save_group .btn_save.dimmed .ico_save {
#       background-color: rgb(103, 132, 118);
#     }
#     .nx_travelsearch .title_area .sub_title .cm_bar{
#       background-color: rgba(103, 132, 118, 0.3);
#     }
#     .nx_travelsearch .detail_info .cm_bar {
#       background-color: rgba(232, 236, 234);
#     }
#     .nx_travelsearch .TopPoi .thumb > .rank {
#       background-color: rgba(73, 111, 93, 0.8);
#     }
#     .nx_travelsearch .TopCity .thumb > .rank {
#       background-color: rgba(73, 111, 93, 0.8);
#     }
#
#     @media (prefers-color-scheme: dark) {
#       .nx_ts_do.is_color_scheme_acceptable .Header {
#         border-top-color: rgba(103, 132, 118, 0.35);
#         background-color: rgb(232, 236, 234);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .title > .details .summary,
#       .nx_ts_do.as_pc.is_color_scheme_acceptable .Header .info {
#         border-color: rgb(73, 111, 93);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .title > .details .summary::before,
#       .nx_ts_do.as_pc.is_color_scheme_acceptable .Header .info::before {
#         border-color: rgba(73, 111, 93, 0.8);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .title > .details {
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .gnb_list::after {
#         background-image: linear-gradient(to left, rgb(232, 236, 234), rgba(232, 236, 234, 0));
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .gnb_list .list {
#         color: rgb(73, 111, 93);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .gnb_list .list .item[aria-selected="true"] .anchor {
#         background-color: rgb(103, 132, 118);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .gnb_list .list .item .anchor::before {
#         background-color: rgba(103, 132, 118, 0.3);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Header .sub_title {
#         color: rgba(73, 111, 93, 0.8);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header.is_fixed .inner {
#         background-color: rgb(232, 236, 234);
#         border-bottom-color: rgba(103, 132, 118, 0.28);
#         box-shadow: 0 0 4px 0 rgba(232, 236, 234, 0.3), 0 2px 3px 0 rgba(0, 0, 0, 0.07);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header.is_fixed_footer .inner {
#         background-color: rgb(232, 236, 234);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .do_content {
#         background-image: linear-gradient(to bottom, rgb(232, 236, 234) 128px, rgb(242, 245, 244) 377px);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .do_content {
#         border-bottom-color: rgba(103, 132, 118, 0.35);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Summary .indent_information,
#       .nx_ts_do.is_color_scheme_acceptable .Info .indent_information {
#         border-left-color: rgba(232, 236, 234, 0.9);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Summary .filters .multiple,
#       .nx_ts_do.is_color_scheme_acceptable .Summary .filters .button[aria-selected="true"],
#       .nx_ts_do.is_color_scheme_acceptable .Reservation .reservation_rooms .types > .button[aria-selected="true"],
#       .nx_ts_do.is_color_scheme_acceptable .Guide .filter .Tag[aria-selected='true'] {
#         border-color: rgba(103, 132, 118, 0.5);
#         color: rgb(73, 111, 93);
#         background-color: rgba(103, 132, 118, 0.03);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Summary .filters .multiple::after {
#         border-top-color: rgb(103, 132, 118);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .tab_list {
#         color: rgb(73, 111, 93);
#         border-color: rgb(103, 132, 118);
#       }
#       .nx_ts_do.as_pc.is_color_scheme_acceptable .Summary .spots .figcaption > .rank {
#         background-color: rgb(73, 111, 93);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Summary .spots .figcaption > .rank {
#         background-color: rgba(73, 111, 93, 0.8);
#       }
#       .nx_ts_do.is_color_scheme_acceptable .Info .alert {
#         color: rgb(73, 111, 93);
#         background-color: rgba(103, 132, 118, 0.06);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .border {
#         border-bottom-color: rgba(103, 132, 118, 0.28);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .top_box {
#         box-shadow: 0 0 4px 0 rgba(103, 132, 118, 0.3), 0 2px 3px 0 rgba(0, 0, 0, 0.07);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .api_save_group .btn_save .ico_save,
#       .nx_travelsearch.is_color_scheme_acceptable .api_save_group .btn_save.dimmed .ico_save {
#         background-color: rgb(103, 132, 118);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .title_area .sub_title .cm_bar{
#         background-color: rgba(103, 132, 118, 0.3);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .detail_info .cm_bar {
#         background-color: rgba(232, 236, 234);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .TopPoi .thumb > .rank {
#         background-color: rgba(73, 111, 93, 0.8);
#       }
#       .nx_travelsearch.is_color_scheme_acceptable .TopCity .thumb > .rank {
#         background-color: rgba(73, 111, 93, 0.8);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header {
#         border-top-color: rgba(103, 132, 118, 0.35);
#         background-color: #303033;
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header.is_fixed .inner {
#         background-color: #303033;
#         box-shadow: none;
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .cities {
#         border-color: rgba(103, 132, 118, 0.3);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .city[aria-selected="true"] {
#         background-color: rgba(73, 111, 93, 0.2);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .do_content {
#         border-bottom-color: rgba(73, 111, 93, 0.3);
#         background-image: none;
#         background-color: #303033;
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .sub_title {
#         color: rgba(73, 111, 93, 0.8);
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Header .gnb_list::after {
#         background-image: linear-gradient(270deg, #303033, rgba(48, 49, 51, 0));
#       }
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Summary .indent_information,
#       .nx_ts_do.as_mo.is_color_scheme_acceptable .Info .indent_information {
#         border-left-color: rgba(73, 111, 93, 0.2);
#       }
#     }
#   </style><div class="Header"><div class="inner"><div class="titles"><div class="title"><h2 class="text">제주특별자치도</h2><div class="info"><button aria-label="도시 바로가기 열고 닫기" class="button" type="button"></button></div></div><div class="sub_title"><span class="text">Jeju</span></div></div><div class="gnb_list"><div class="inner"><ul class="list" role="tablist"><li aria-selected="false" class="item" role="tab"><a aria-selected="false" class="anchor" href="#"><span class="text">전체</span></a></li><li aria-selected="false" class="item" role="tab"><a aria-selected="false" class="anchor" href="#"><span class="text">여행정보</span></a></li><li aria-selected="false" class="item" role="tab"><a aria-selected="false" class="anchor" href="#"><span class="text">예약하기</span></a></li><li aria-selected="true" class="item" role="tab"><a aria-selected="false" class="anchor" href="#"><span class="text">도시정보</span></a></li></ul></div></div></div></div><div class="do_content"><div class="Info"><div class="do_card"><div class="do_cardhead"><h3 class="subject">도시정보</h3></div><a aria-selected="false" class="alert" href="https://jeju.go.kr/covid19.jsp" rel="noreferrer noopener" target="_blank"><span class="highlighted">안내</span><span class="text">제주 코로나19 신규 확진자 5명</span></a><p class="description">한국·중국·일본 등 극동 지역의 중앙부에 있어 지정학적으로도 중요하며, 도 전체가 바다로 둘러싸였다. 수리적(數理的)으로는 동경 126°08'∼126°58', 북위 33°06'∼34°00'에 위치한다. 북단은 북위 34°00'의 제주시 추자면 대서리이며, 남단은 북위 33°06'의 서귀포시 대정읍 마라도다. 한국 최남단에 있는 도로서, 제주도를 포함해 9개의 유인도와 55개의 무인도로 이루어졌다. 이 가운데 유인도는 우도·상추자도·하추자도·비양도·횡간도·추포도·가파도·마라도이다. 남북 간의 거리가 약 31㎞, 동서간의 거리가 약 73㎞로 동서로 가로놓인 모양이다. 러시아·중국 등의 대륙과 일본·동남아 등지를 연결하는 요충지이며, 천혜의 자연경관이 수려한 세계적인 휴양관광지다.</p><div class="indent_information"><div class="item"><span class="criteria">관련</span><span class="value"><a aria-selected="false" class="anchor" href="https://www.visitjeju.net/kr" rel="noreferrer noopener" target="_blank">비짓제주</a><a aria-selected="false" class="anchor" href="https://map.naver.com/v5/search/%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84" rel="noreferrer noopener" target="_blank">지도</a></span></div><div class="item"><span class="criteria">행정구역</span><span class="value"><a aria-selected="false" class="area" href="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84+%EC%A0%9C%EC%A3%BC%EC%8B%9C&amp;mra=RFJUX1RSQQ%3D%3D&amp;x_bifrost=%7B%22nqx%22%3A%7B%22rcode%22%3A%2214110%22%2C%22ptnCode%22%3A%22info%22%7D%7D&amp;sm=tab_clk.dtr" rel="noreferrer noopener" target="_self">제주시</a><a aria-selected="false" class="area" href="https://search.naver.com/search.naver?where=nexearch&amp;query=%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84+%EC%84%9C%EA%B7%80%ED%8F%AC%EC%8B%9C&amp;mra=RFJUX1RSQQ%3D%3D&amp;x_bifrost=%7B%22nqx%22%3A%7B%22rcode%22%3A%2214130%22%2C%22ptnCode%22%3A%22info%22%7D%7D&amp;sm=tab_clk.dtr" rel="noreferrer noopener" target="_self">서귀포시</a></span></div></div></div><div class="do_card"><div class="do_cardhead"><h3 class="subject">날씨정보</h3></div><div class="weather_panel"><div class="today"><span aria-label="맑음" class="weather as_2"></span><div class="info"><b class="now"><span class="value">25</span><sup class="sup">℃</sup></b><p class="summary">맑음. 어제보다 3˚ 낮아요</p><div class="temperatures"><div class="extreme"><span class="lowest">26<!-- -->°</span><span class="highest">31<!-- -->°</span></div><div class="experience"><span class="text">체감온도</span><span class="value">26.5<!-- -->℃</span></div></div><div class="precipitation"><span class="text">강수 확률</span><b class="value">0<!-- -->%</b></div></div><div class="side"><div class="item"><span class="subject">미세먼지</span><span class="value as_good">12㎍/㎥ 좋음</span></div><div class="item"><span class="subject">초미세먼지</span><span class="value as_good">2㎍/㎥ 좋음</span></div></div></div><div class="ScrollBox days"><div class="scroll"><ul class="list"><li aria-hidden="true" class="observer"></li><li class="item as_first"><div class= ...
# <script>
#   typeof window.naver === 'undefined' && (window.naver = {});
#   naver.search = naver.search || {};
#   naver.search.ext = naver.search.ext || {};
#   naver.search.ext.travelSearch = naver.search.ext.travelSearch || {};
#   naver.search.ext.travelSearch.__CONTEXT__ = {"placeId":"14","ptnCode":"info","where":"nexearch","nscs":"0"};
#   naver.search.ext.travelSearch.__APOLLO_STATE__ = {"ROOT_QUERY":{"__typename":"Query","domesticCommonInfo({\"rcode\":\"14\"})":{"__typename":"DomesticCommonInfo","nameKo":"제주","nameEn":"Jeju","exposeTitle":"제주특별자치도","themeColor":[[103,132,118],[73,111,93],[232,236,234],[242,245,244]],"darkModeThemeColor":[[103,132,118],[73,111,93],[232,236,234],[242,245,244]],"tabList":["summary","guide","reservation","info"],"defaultProduct":"항공권","defaultAccommoProduct":"호텔","naviCities":[{"__typename":"TinyCityInfo","rcode":"14","nameKo":"제주","exposeTitle":"제주특별자치도"},{"__typename":"TinyCityInfo","rcode":"01","nameKo":"강원","exposeTitle":"강원도"},{"__typename":"TinyCityInfo","rcode":"08","nameKo":"부산","exposeTitle":"부산광역시"},{"__typename":"TinyCityInfo","rcode":"09","nameKo":"서울","exposeTitle":"서울특별시"},{"__typename":"TinyCityInfo","rcode":"02","nameKo":"경기","exposeTitle":"경기도"},{"__typename":"TinyCityInfo","rcode":"11","nameKo":"인천","exposeTitle":"인천광역시"},{"__typename":"TinyCityInfo","rcode":"16","nameKo":"충북","exposeTitle":"충청북도"},{"__typename":"TinyCityInfo","rcode":"15","nameKo":"충남","exposeTitle":"충청남도"},{"__typename":"TinyCityInfo","rcode":"04","nameKo":"경북","exposeTitle":"경상북도"},{"__typename":"TinyCityInfo","rcode":"03","nameKo":"경남","exposeTitle":"경상남도"},{"__typename":"TinyCityInfo","rcode":"13","nameKo":"전북","exposeTitle":"전라북도"},{"__typename":"TinyCityInfo","rcode":"12","nameKo":"전남","exposeTitle":"전라남도"}]},"domesticGeoInfo({\"rcode\":\"14\"})":{"__typename":"DomesticTravelDocument","hotel({\"from\":0,\"size\":1})":{"__typename":"HotelData","hotels":[{"__typename":"HotelProduct","name":"랜딩관 제주신화월드 호텔앤리조트"}]},"resort({\"from\":0,\"size\":1})":{"__typename":"HotelData","hotels":[{"__typename":"HotelProduct","name":"더큐브 리조트 제주"}]},"pension({\"from\":0,\"size\":1})":{"__typename":"GlaceProductData","products":[{"__typename":"GlaceItem","title":"더갤러리펜션"}]},"camping({\"from\":0,\"size\":1})":{"__typename":"GlaceProductData","products":[{"__typename":"GlaceItem","title":"제주플래티늄카라반"}]},"airportInfo":{"__typename":"Airport","iataCode":"CJU","cityName":"제주"},"pkgtour({\"size\":1})":{"__typename":"DomesticSearchResultNx","productList":[{"__typename":"DomesticProductItemNx","productId":"summer-20210822"}]},"rcode":"14","nameKo":"제주","descendants":[{"__typename":"Descendants","exposeTitle":"제주특별자치도 제주시","rcode":"14110","name":"제주시"},{"__typename":"Descendants","exposeTitle":"제주특별자치도 서귀포시","rcode":"14130","name":"서귀포시"}],"dictInfo":{"__typename":"DomesticDictInfo","description":"한국·중국·일본 등 극동 지역의 중앙부에 있어 지정학적으로도 중요하며, 도 전체가 바다로 둘러싸였다. 수리적(數理的)으로는 동경 126°08'∼126°58', 북위 33°06'∼34°00'에 위치한다. 북단은 북위 34°00'의 제주시 추자면 대서리이며, 남단은 북위 33°06'의 서귀포시 대정읍 마라도다. 한국 최남단에 있는 도로서, 제주도를 포함해 9개의 유인도와 55개의 무인도로 이루어졌다. 이 가운데 유인도는 우도·상추자도·하추자도·비양도·횡간도·추포도·가파도·마라도이다. 남북 간의 거리가 약 31㎞, 동서간의 거리가 약 73㎞로 동서로 가로놓인 모양이다. 러시아·중국 등의 대륙과 일본·동남아 등지를 연결하는 요충지이며, 천혜의 자연경관이 수려한 세계적인 휴양관광지다."},"homepage":"https://www.visitjeju.net/kr","homepageTitle":"비짓제주","mapLinkPc":"https://map.naver.com/v5/search/%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84","mapLinkMo":"https://m.map.naver.com/viewer/map.naver?pinTitle=%EC%A0%9C%EC%A3%BC%ED%8A%B9%EB%B3%84%EC%9E%90%EC%B9%98%EB%8F%84&lng=126.49827&lat=33.488994&rcode=14&isShowPolygon=true&isDetailAddress=false","keywords":{"__typename":"Keywords","total":["흑돼지","오메기떡","미로공원","고등어회","전복뚝배기","성게미역국","돔베고기","갈치회","카약","유채꽃밭","감귤체험","낚시체험","사진찍기좋은"]},"covid":{"__typename":"CovidStatus","key":"제주","diff":5,"url":"https://jeju.go.kr/covid19.jsp"},"weatherInfo":{"__typename":"DomesticWeatherInfo","today":{"__typename":"DomesticWeatherToday","weatherCode":"2","weatherText":"맑음","currTemperature":25,"feelTemperature":26.5,"minTemperature":26,"maxTemperature":31,"diffTemperature":-3,"rainfall":{"__typename":"Rainfall","rainProb":"0","rainAmt":0,"todayRainAmt":0,"snowAmt":"-","minRainAmt":0,"maxRainAmt":2},"dust":{"__typename":"DustInfo","airPollutionData":{"__typename":"AirPollutionData","value":"12","legend":"좋음","todayAmValue":"좋음","today ...
#
#   </script>
# <script>
#     (function (urls) {
#       var newUrls = urls;
#       if (!(newUrls && newUrls.length > 0)) return;
#       for (var i = 0; i < newUrls.length; i++) {
#         window.nhn.common.load_js(newUrls[i], function () {}, false);
#       }
#     })(['https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/runtime~main-bundle-835eb794.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/main-bundle-d67f7605.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/components-mainContainer-bundle-33a0694e.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/13-bundle-9840ee10.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/11-bundle-df8350c9.js','https://vbs.pstatic.net/assets/deploy-travel/domestic-nx/210805-0cc40fb/dist/web/pages-info-bundle-c92a63f1.js']);
#     </script>
# <script id="__LOADABLE_REQUIRED_CHUNKS__" type="application/json">[1,13,11,4]</script><script id="__LOADABLE_REQUIRED_CHUNKS___ext" type="application/json">{"namedChunks":["components-mainContainer","pages-info"]}</script>
# </div>
# <script type="text/javascript">var g_uad = false; </script><!--NX 96397a260d027d322ed9abbce76a0fba--> <script> nco_area_p9001 = "nco_x2h*2"; nco_area_19123281 = "nco_x2h*2"; nco_gdid_p9001 = "00000015_00000123CC51"; nco_gdid_19123281 = "00000015_00000123CC51"; </script> <script type="text/javascript"> nhn = window.nhn || {}; nhn.dss = nhn.dss || {}; nhn.dss.x2hBase = { name : 'cpeditor', desc : '컨텐츠 검색', agentIsMac : $Agent().os().mac }; </script> <div class="content_search section" data-dss-logarea="x2h"> <div class="contents03 "> <div class="contents03_sub"> <a class="api_banner" href="https://travel-event.naver.com/promotion/jejutour" onclick='return goOtherCR(this,"a=nco_x2h*2&amp;r=1&amp;i="+urlencode("00000015_00000123CC51")+"&amp;u="+urlencode(this.href));' style="background-color:#127bff;"><img alt="네이버 국내투어에서 제주도 여행상품 구매시 N Pay 7%적립" height="62" src="https://ssl.pstatic.net/sstatic/search/mobile/tmp/ban_outer_c5fec0d306a8978019bdb6fd20583a20.png" width="320"/></a> </div> </div> </div> <script crossorigin="anonymous" src="https://ssl.pstatic.net/adimg3.search/adpost/js/event_tracker.js?o=search"></script>
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
# <link href="https://ssl.pstatic.net/sstatic/search/sa/210506/css/powerlink.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css"/>
# <div class="ad_section section _pl_section bg_type_v2">
# <div class="section_head nx_power"><h2>파워링크</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em><strong class="dsc_ncaution_keyword">제주도</strong><em class="dsc_ncaution_quotation">’</em></span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowPl(this)) goOtherCR(this, 'a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a class="link_help" href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704">도움말</a></p>
# <button class="bt_ad_clse" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ad_area nx_power" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=7pF6xFxnYDA97-d_...-...">
# <ul class="lst_type">
# <li class="lst type_more type_subtitle type_img " num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=orQl9l8/i5Eqz1Zc4M3b7f///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAxOTA2MThfMTE1/MDAxNTYwODI2OTg0Mjc1.SI2hTTKp9NPxammC4SW5VPhMJ3sOYZtPgHlRAfiDdCUg.5DeNAfqA_ogbskzNycbrLwEoRYWhCtyZ2ZFuXu333Awg.JPEG/570523-125f8ba7-f314-4fc3-95b5-1d394ee28235.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=iYUm8jTS/1cQXt1XHigKMf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d=' + urlencode('http://www.tmon.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주도 티몬</div>
# <div class="sub_tit">릴레이쿠폰혜택+결제할인!</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_ad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <p>네이버 아이디로 로그인이 가능합니다.</p>
# <p class="ly_ad_go">서비스 자세히 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=iYUm8jTS/1cQXt1XHigKMf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000121255227&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.tmon.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">제주도</strong>, 제주여행의 모든 것! <strong class="hl">제주도</strong> 인기호텔/렌터카/액티비티/입장권 할인!
#
#             </p></div>
# </div>
# </li>
# <li class="lst type_more ext_desc type_img " num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=tBmB/7PixixEp6cuypS8z////w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000054503425&amp;d='+urlencode('http://www.agoda.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAxOTAzMjFfODYg/MDAxNTUzMTU3NjA0ODU5.VQ-wC6A_LY-b9A5c5uzD4j5ODJmE2NZ6TQWXV6UFe88g.0wiLwgAht8DhDEv7OegEgT7cYiEoyCZAlENm3NNdyvUg.JPEG/364433-53fde1f2-982a-4351-98ff-c671ca0e1b61.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=xo5JvVayr0gknkzkPl8kKf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000054503425&amp;d=' + urlencode('http://www.agoda.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">최저가호텔예약은 역시 아고다</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=xo5JvVayr0gknkzkPl8kKf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000054503425&amp;d='+urlencode('http://www.agoda.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.agoda.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               맘에 드는 호텔 선예약으로 지르고, 결제는 나중에 숙소에서! 호텔예약 아고다
#
#             </p></div>
# <p class="ad_dsc promotion">
#
#               인기 호텔 당일 예약가능!
#             </p>
# </div>
# </li>
# <li class="lst type_more ext_link type_img " num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=ZjWUjlJ42wc7ktznrO6xXv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000138678024&amp;d='+urlencode('https://www.hyatt.com/ko-KR/hotel/south-korea/grand-hyatt-jeju/cjugh')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMTA4MDJfMjY0/MDAxNjI3ODkyNDk5MTE3.j0orVZSl3DaRzbgAU_KfsfG204tgGWkL1XpGlues_eEg.ySzR7GWvAMrfP6KDBxLjpKaQX4XYOl7NmwTc6c1uO3Ug.JPEG/2082712-d0bdff62-e49e-4a95-80dc-edeb5f3969b2.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=zAlqfmiSws/MQhWBOjWtgv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000138678024&amp;d=' + urlencode('https://www.hyatt.com/ko-KR/hotel/south-korea/grand-hyatt-jeju/cjugh') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">그랜드 하얏트 제주</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=zAlqfmiSws/MQhWBOjWtgv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000138678024&amp;d='+urlencode('https://www.hyatt.com/ko-KR/hotel/south-korea/grand-hyatt-jeju/cjugh')+'&amp;u='+urlencode(this.href));" target="_blank">www.hyatt.com/ko-KR/hotel/south-korea/grand...</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               객실 15% 혜택 받고, 야외 풀데크에서 칵테일을 마시며 시원한 호캉스를 즐기세요
#
#             </p></div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=VvjmKy4eA4oQnsKs+x/b9v///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000138678024&amp;d='+urlencode('https://www.hyatt.com/ko-KR/hotel/south-korea/grand-hyatt-jeju/cjugh')+'&amp;u='+urlencode(this.href));" target="_blank">시그넷 팝업</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=zbDtUCtD1gHigFcCVlzfmf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000138678024&amp;d='+urlencode('https://www.hyatt.com/ko-KR/hotel/south-korea/grand-hyatt-jeju/cjugh')+'&amp;u='+urlencode(this.href));" target="_blank">일식 런치</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=QPE1Yah8JbDEeACGeFe7v////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000138678024&amp;d='+urlencode('https://www.hyatt.com/ko-KR/hotel/south-korea/grand-hyatt-jeju/cjugh')+'&amp;u='+urlencode(this.href));" target="_blank">음료 1+1</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=Jv7bgyjb7lSyqhdqyImoUv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000138678024&amp;d='+urlencode('https://www.hyatt.com/ko-KR/hotel/south-korea/grand-hyatt-jeju/cjugh')+'&amp;u='+urlencode(this.href));" target="_blank">뷔페 3+1</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more ext_link type_img " num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=HcIvmQBZA5Hw/ctS/Orwz////w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=4&amp;i=nad-a001-01-000000139163282&amp;d='+urlencode('http://www.frip.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMTA2MThfMjYy/MDAxNjIzOTg5OTYwMzMx.eloau1KCGvYrZtzzMmHV7ApU0yUV0GdulbEnmu0faFwg.KkRyBU4lBJhgrxmS5U5maqSDs1WDA1Ikgy-qU412K3Yg.JPEG/795107-6d2359be-9a2a-45be-bf58-faafeea65265.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=Zlec1A1yq3nAKmHlNvKihv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000139163282&amp;d=' + urlencode('http://www.frip.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주도여행도 프립으로</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=Zlec1A1yq3nAKmHlNvKihv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000139163282&amp;d='+urlencode('http://www.frip.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.frip.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">제주도</strong>여행 시작은 프립! <strong class="hl">제주도</strong> 맛집투어부터 원데이클래스까지 간편하게 예약. 프립
#
#             </p></div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=dkyfSNcNjJi/RSYB5hjtCv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=4&amp;i=nad-a001-01-000000139163282&amp;d='+urlencode('http://www.frip.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">제주서핑</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=FDue44iWZeIaLJMUDvMNlv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=4&amp;i=nad-a001-01-000000139163282&amp;d='+urlencode('http://www.frip.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">제주맛집탐방</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=wvaEgOVCxg84XZ9aCcNAev///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=4&amp;i=nad-a001-01-000000139163282&amp;d='+urlencode('http://www.frip.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">감성게하</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=pFbi9GdbKOftOqylqOlst////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=4&amp;i=nad-a001-01-000000139163282&amp;d='+urlencode('http://www.frip.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">제주도캠핑</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_img " num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=NXVfOTxmYY3Axutuq0gFSv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000084809080&amp;d='+urlencode('https://smartstore.naver.com/sdonwoori-co')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="70" src="https://searchad-phinf.pstatic.net/MjAyMDAyMDVfMjQ1/MDAxNTgwODc3NDA4ODI1.wOOsGnKOK0cFnLMhR1T5QzHuAvAyKThGQ5vG7D__bL0g.XRXYton9PUSWyjsa_gsSx3ye1HYCL6JbzcwV6N7V2Vsg.JPEG/1312400-529bd58b-fb0e-4e56-9d7d-dca4c8925e5c.jpg?type=f120_120" width="70"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=L24tIFf8RV32jDQqF1+qA////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000084809080&amp;d=' + urlencode('https://smartstore.naver.com/sdonwoori-co') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">냉장제주흑돼지 직송,생돈우리</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay_plus" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.checkout&amp;r=5&amp;i=nad-a001-01-000000084809080&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=L24tIFf8RV32jDQqF1+qA////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000084809080&amp;d='+urlencode('https://smartstore.naver.com/sdonwoori-co')+'&amp;u='+urlencode(this.href));" target="_blank">smartstore.naver.com/sdonwoori-co</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               제주흑돼지 맛집에서 직접 보내는 30시간 숙성 제주흑돼지.
#
#             </p></div>
# </div>
# </li>
# <li class="lst type_more " num="5" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=qIqNqRbavJorICWWhE/26f///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000092827721&amp;d=' + urlencode('http://www.lotteimall.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주도 롯데홈쇼핑</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.checkout&amp;r=6&amp;i=nad-a001-01-000000092827721&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=qIqNqRbavJorICWWhE/26f///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000092827721&amp;d='+urlencode('http://www.lotteimall.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.lotteimall.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               제주 숙소/패키지까지, 제주여행혜택으로 더해지는 여행의 즐거움!<strong class="hl">제주도</strong>
# </p></div>
# </div>
# </li>
# <li class="lst type_more " num="6" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=e6xJO/yfnovVAmdxyFPpgv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000116741745&amp;d=' + urlencode('http://gtour.gmarket.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">G마켓여행 제주도</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=e6xJO/yfnovVAmdxyFPpgv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000116741745&amp;d='+urlencode('http://gtour.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">gtour.gmarket.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               전국 핫스팟을 G마켓여행 특가로! 스마일클럽은 5% 중복 할인!
#
#             </p></div>
# </div>
# </li>
# <li class="lst type_line " num="7" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="line"></div>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=GZZCi9mc5XAb9sruawQ+LP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000144481801&amp;d=' + urlencode('https://www.lotteon.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주도,롯데ON</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.checkout&amp;r=8&amp;i=nad-a001-01-000000144481801&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=GZZCi9mc5XAb9sruawQ+LP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000144481801&amp;d='+urlencode('https://www.lotteon.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.lotteon.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">제주도</strong> 쇼핑의 모든 것, 이번주만 15%쿠폰팩+8천점적립+카드 7%할인 혜택!
#
#             </p></div>
# </div>
# </li>
# <li class="lst " num="8" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=1cuhLX3l9ApoM5wq3wkOoP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=9&amp;i=nad-m001-01-000001897827107&amp;d=' + urlencode('http://jejutourmg.com/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주투어매니저</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=1cuhLX3l9ApoM5wq3wkOoP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=9&amp;i=nad-m001-01-000001897827107&amp;d='+urlencode('http://jejutourmg.com/')+'&amp;u='+urlencode(this.href));" target="_blank">jejutourmg.com/</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               오메기떡 이벤트, 항공, 숙소, 렌트 반값여행, 단체여행 특전, 친절전화상담
#
#             </p></div>
# </div>
# </li>
# ...
# <script> /* [AU] 인라인 스크립트 */ (function () { var CLASS_SECTION = "_sp_ntotal"; var CLASS_MARGIN = "type_margin"; var sectionEls = Array.prototype.slice.call(document.querySelectorAll("section." + CLASS_SECTION)); function matches(element, selector) { if (element.matches) return element.matches(selector); if (element.msMatchesSelector) return element.msMatchesSelector(selector); return false; } /* 연속되는 섹션 요소인지 검사한다. */ function isNextSiblingSection(sectionEl) { var targetEl = sectionEl; var targetTagName = targetEl.tagName.toLowerCase(); do { targetEl = targetEl.previousElementSibling; targetTagName = targetEl ? targetEl.tagName.toLowerCase() : ""; } while ( targetEl !== null && ( targetTagName === "script" || targetTagName === "link" ) ); if (targetEl === null) { return false; } return ( targetTagName === "section" && matches(targetEl, "." + CLASS_SECTION) ); } for (var i = 0; i < sectionEls.length; ++i) { if (isNextSiblingSection(sectionEls[i])) { sectionEls[i].classList.add(CLASS_MARGIN); } } })(); </script> <script type="text/javascript">
#     var _elAdIndLayerBz = null;
#     var _elAdIndLayerTimeBz;
#     var _elDscNcautionBz = null;
#
#     function adInfoShowBz(el) {
#       if (_elAdIndLayerBz) {
#         adInfoHideBz();
#         return false;
#       } else {
#         if (!_elDscNcautionBz) {
#           _elDscNcautionBz = $Element(el).parent();
#         }
#         _elDscNcautionBz._element.style.zIndex = 121;
#         _elAdIndLayerBz = $Element(el).next();
#         _elAdIndLayerBz.show();
#         _elAdIndLayerTimeBz = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHideBz() {
#       if (_elAdIndLayerBz) {
#         if (_elDscNcautionBz) {
#           _elDscNcautionBz._element.style.zIndex = 0;
#         }
#         _elAdIndLayerBz.hide();
#         _elAdIndLayerBz = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerBz(e) {
#       if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#   </script>
# <div class="ad_section section _bz_section bg_type_v2">
# <div class="section_head"><h2>비즈사이트</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">제주도</strong>
# <em class="dsc_ncaution_quotation">’</em>
# </span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="ico_ad_dsc" href="javascript:void(0);" onclick="if(adInfoShowBz(this)) goOtherCR(this, 'a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
# <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="ad_area nx_power" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=...-...">
# <ul class="lst_type ">
# <li class="lst" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=lvV+LaTwq382kwrUL6FHm////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000097781445&amp;d=' + urlencode('http://www.gmarket.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">G마켓 제주도</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=lvV+LaTwq382kwrUL6FHm////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000097781445&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.gmarket.co.kr</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               쇼핑을 바꾸는 쇼핑! <strong class="hl">제주도</strong> 스마일클럽은 12% 할인 + 스마일배송 무료배송
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=KYY3X2RyI1OTB1KKQAmL7f///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000130582449&amp;d=' + urlencode('https://smartstore.naver.com/thekooh_') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">독특한 생활소품 제주도</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay_plus" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.checkout&amp;r=2&amp;i=nad-a001-01-000000130582449&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=KYY3X2RyI1OTB1KKQAmL7f///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000130582449&amp;d='+urlencode('https://smartstore.naver.com/thekooh_')+'&amp;u='+urlencode(this.href));" target="_blank">smartstore.naver.com/thekooh_</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               환경친화적인 소재를 사용한 독특한 디자인 퀄리 <strong class="hl">제주도</strong> 고릴라가라지
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=rVwNNnEvATWkm9ggQS1+Rf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=3&amp;i=nad-m001-01-000001804746735&amp;d=' + urlencode('http://www.jejuaratour.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">나만의제주여행 제주아라투어</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=rVwNNnEvATWkm9ggQS1+Rf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=3&amp;i=nad-m001-01-000001804746735&amp;d='+urlencode('http://www.jejuaratour.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.jejuaratour.com</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               내가 만드는 나의제주여행! 항공, 펜션, 렌터카, 유류할증료 공항이용료 포함금액!
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=Av1dLL+xVz+wkdDT8EE69v///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000140958704&amp;d=' + urlencode('https://haejone.modoo.at/') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">제주해조네 보말성게전문점</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=Av1dLL+xVz+wkdDT8EE69v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000140958704&amp;d='+urlencode('https://haejone.modoo.at/')+'&amp;u='+urlencode(this.href));" target="_blank">haejone.modoo.at/</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
# <strong class="hl">제주도</strong> 보말 과 성게만 사용하여 17년 경력에 어머니가 요리를 하고 있습니다.
#
#             </p></div>
# </div>
# </li>
# <li class="lst" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=yrqSWUehOj4xUVBoS/endv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000142632776&amp;d=' + urlencode('https://smartstore.naver.com/againjeju') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <div class="lnk_tit">어게인제주-제주 무드등 캔들</div>
# </a>
# <div class="url_area">
# <span class="ico_ad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_ad ico_npay_plus" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <span class="txt_reward">3%</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.checkout&amp;r=5&amp;i=nad-a001-01-000000142632776&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <p>네이버 아이디 하나로 간편구매</p>
# <p class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_ad bu"></span></p>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=yrqSWUehOj4xUVBoS/endv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000142632776&amp;d='+urlencode('https://smartstore.naver.com/againjeju')+'&amp;u='+urlencode(this.href));" target="_blank">smartstore.naver.com/againjeju</a>
# </div>
# <div class="ad_dsc"><p class="ad_dsc_inner">
#               제주캔들, 제주바다캔들, LED캔들, 제주기념품<strong class="hl">제주도</strong>
# </p></div>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;referenceId=heseodp0JywssM6Lt%2Bssssssskd-188461&amp;bucket=0" onclick="return goOtherCR(this, 'a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_ad"></i></a>
# </div>
# </div>
# </div>
# <div class="api_sc_page_wrap"> <div class="sc_page"> <a aria-disabled="true" class="btn_prev" role="button"><i class="spnew ico_page_arr">이전</i></a> <div class="sc_page_inner"> <a aria-pressed="true" class="btn" href="?query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;sm=tab_pge&amp;where=nexearch" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=1&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">1</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=2&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=2&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">2</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=3&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=3&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">3</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=4&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=4&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">4</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=5&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=5&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">5</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=6&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=6&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">6</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=7&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=7&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">7</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=8&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=8&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">8</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=9&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=9&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">9</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=10&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=121&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=10&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">10</a> </div> <a aria-disabled="false" class="btn_next" href="?display=15&amp;f=&amp;filetype=0&amp;page=11&amp;query=%EC%A0%9C%EC%A3%BC%EB%8F%84&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=11&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button"><i class="spnew ico_page_arr">다음</i></a> </div> </div> <section class="sc_new sp_nkeyword" id="nx_footer_related_keywords"> <div class="api_subject_bx _related_box"> <div class="api_title_area"> <h2 class="api_title">연관 검색어<a class="api_link_help" href="https://help.naver.com/support/alias/search/word/word_1.naver" onclick="return  ...

# %%
title = soup.find('a')
title
# Out:
# <a href="#lnb"><span>메뉴 영역으로 바로가기</span></a>

# %%
title.get_text()
# Out:
# '메뉴 영역으로 바로가기'

# %%
# keyword로 class를 사용할 때는 _를 붙여주어야 함
# 파이썬의 클래스와 중복되기 떼문
title = soup.find_all('a', class_="api_txt_lines total_tit")
title
# Out:
# [<a class="api_txt_lines total_tit" data-recommend="1" href="https://blog.naver.com/findjeju/222422079498" onclick="return goOtherCR(this, 'a=rvw*w.link&amp;r=1&amp;i=90000003_0000000000000033C963980A&amp;u='+urlencode(this.href))" target="_blank">혜택이 쏠쏠한 <mark>제주도</mark> 펜션</a>,
#  <a class="api_txt_lines total_tit" data-recommend="1" href="https://blog.naver.com/uni7741/222445065288" onclick="return goOtherCR(this, 'a=rvw*w.link&amp;r=2&amp;i=90000003_0000000000000033CAC25448&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 관광택시 너무 편했던 제주 카니발렌트</a>,
#  <a class="api_txt_lines total_tit" data-recommend="1" href="https://cafe.naver.com/hotellife/1647145" onclick="return goOtherCR(this, 'a=rvw*t.link&amp;r=3&amp;i=90000004_011EA92D0019222900000000&amp;u='+urlencode(this.href))" target="_blank">6월에 갔던 <mark>제주도</mark> 신혼여행</a>,
#  <a class="api_txt_lines total_tit" data-recommend="1" href="https://blog.naver.com/nailstan/222452818827" onclick="return goOtherCR(this, 'a=rvw*f.link&amp;r=4&amp;i=90000003_0000000000000033CB38A38B&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 택시투어 제주 관광코스 여유롭게 힐링여행</a>,
#  <a class="api_txt_lines total_tit" data-recommend="1" href="https://blog.naver.com/lightsout/222430815485" onclick="return goOtherCR(this, 'a=rvw*f.link&amp;r=5&amp;i=90000003_0000000000000033C9E8E4FD&amp;u='+urlencode(this.href))" target="_blank">제주 서쪽 가볼만한곳 <mark>제주도</mark> 금오름 탐방</a>,
#  <a class="api_txt_lines total_tit" data-recommend="1" href="https://blog.naver.com/bahna2/222436905422" onclick="return goOtherCR(this, 'a=rvw*f.link&amp;r=6&amp;i=90000003_0000000000000033CA45D1CE&amp;u='+urlencode(this.href))" target="_blank">그랜드 하얏트 제주 호텔 룸과 수영장 <mark>제주도</mark> 호캉스</a>,
#  <a class="api_txt_lines total_tit" data-recommend="1" href="https://blog.naver.com/gx339s/222457748310" onclick="return goOtherCR(this, 'a=rvw*b.link&amp;r=7&amp;i=90000003_0000000000000033CB83DB56&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 수영장 호텔, 썬라이즈 제주 중문점</a>,
#  <a class="api_txt_lines total_tit" data-recommend="1" href="https://blog.naver.com/nose1032/222457903302" onclick="return goOtherCR(this, 'a=rvw*b.link&amp;r=8&amp;i=90000003_0000000000000033CB8638C6&amp;u='+urlencode(this.href))" target="_blank">성공적인 <mark>제주도</mark> 여행 코스</a>,
#  <a class="api_txt_lines total_tit" data-recommend="1" href="https://blog.naver.com/jeju8253/222441611073" onclick="return goOtherCR(this, 'a=rvw*f.link&amp;r=9&amp;i=90000003_0000000000000033CA8D9F41&amp;u='+urlencode(this.href))" target="_blank"><mark>제주도</mark> 가볼만한곳 7월 2박3일 여행코스 중에 제주 새별오름</a>]

# %%
# 배열에 저장
all_title = [item.get_text() for item in title]
all_title
# Out:
# ['혜택이 쏠쏠한 제주도 펜션',
#  '제주도 관광택시 너무 편했던 제주 카니발렌트',
#  '6월에 갔던 제주도 신혼여행',
#  '제주도 택시투어 제주 관광코스 여유롭게 힐링여행',
#  '제주 서쪽 가볼만한곳 제주도 금오름 탐방',
#  '그랜드 하얏트 제주 호텔 룸과 수영장 제주도 호캉스',
#  '제주도 수영장 호텔, 썬라이즈 제주 중문점',
#  '성공적인 제주도 여행 코스',
#  '제주도 가볼만한곳 7월 2박3일 여행코스 중에 제주 새별오름']

# %% [markdown]
# ## Selenium

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in /usr/local/lib/python3.7/dist-packages (3.141.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from selenium) (1.24.3)

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# path 변수에 자신의 chromedriver가 있는 파일 위치를 할당
# window : ~/chromedriver.exe
# mac : ~/chromedriver (.exe 빼기) 
# path = 'C:/Users/bluea/chromedriver.exe'
# driver = webdriver.Chrome(path)
driver = webdriver.Chrome('C:/Users/bluea/chromedriver.exe')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/common/service.py in start(self)
#      75                                             stderr=self.log_file,
# ---> 76                                             stdin=PIPE)
#      77         except TypeError:
#
# /usr/lib/python3.7/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# /usr/lib/python3.7/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1550                             err_msg += ': ' + repr(err_filename)
# -> 1551                     raise child_exception_type(errno_num, err_msg, err_filename)
#    1552                 raise child_exception_type(err_msg)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/bluea/chromedriver.exe': 'C:/Users/bluea/chromedriver.exe'
#
# During handling of the above exception, another exception occurred:
#
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-35-3b36fec63940> in <module>()
#       7 # path = 'C:/Users/bluea/chromedriver.exe'
#       8 # driver = webdriver.Chrome(path)
# ----> 9 driver = webdriver.Chrome('C:/Users/bluea/chromedriver.exe')
#
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/chrome/webdriver.py in __init__(self, executable_path, port, options, service_args, desired_capabilities, service_log_path, chrome_options, keep_alive)
#      71             service_args=service_args,
#      72             log_path=service_log_path)
# ---> 73         self.service.start()
#      74
#      75         try:
#
# /usr/local/lib/python3.7/dist-packages/selenium/webdriver/common/service.py in start(self)
#      81                 raise WebDriverException(
#      82                     "'%s' executable needs to be in PATH. %s" % (
# ---> 83                         os.path.basename(self.path), self.start_error_message)
#      84                 )
#      85             elif err.errno == errno.EACCES:
#
# WebDriverException: Message: 'chromedriver.exe' executable needs to be in PATH. Please see https://sites.google.com/a/chromium.org/chromedriver/home

# %%
'''
# webdriver에 옵션 적용 가능
options = webdriver.ChromeOptions()

# 브라우저 창이 안뜨고 실행
options.add_argument('headless')
# 브라우저 사이즈 설정
options.add_argument('window-size=1920x1080')

# 옵션 적용
driver = webdriver.Chrome(path, options=options)
'''

# %%
driver.get('https://www.naver.com/')

# id 속성으로 검색창 찾기
search = driver.find_element_by_id('query')

# 검색어 입력
search.send_keys('제주도')
# Keys.RETURN = Enter 입력
search.send_keys(Keys.RETURN)


# a 태그의 텍스트로 찾기
search = driver.find_element_by_link_text('이미지')
# 클릭
search.click()

# %% [markdown]
# \* 셀레니움 사용 시 브라우저에서 해당 웹 페이지의 요소들을 로드하는 데 시간이 좀 걸리기 때문에, element가 존재하지 않는다는 error가 발생할 수 있다.
# 그럴 경우 해당 요소가 전부 준비가 될 때까지 대기해야 한다.
#
# ```python
# driver.implicitly_wait(time_to_wait=5)
# ```
# -> 찾으려는 element가 로드될 때까지 지정한 시간만큼 대기할 수 있도록 설정
# 위 방법은 암시적 대기 방식으로, webdriver에 영구적으로 작용된다.
# time_to_wait=5: 5초까지 기다림
#
# https://workingwithpython.com/selenium-waits/

# %%
driver.get('https://finance.naver.com/')

all_title=[]

for i in range(1,5):
    # css 선택자로 찾기
    # 크롬 개발자 도구에서 copy selector를 이용하면 편함
    css = '#content > div.article > div.section > div.news_area > div > ul > li:nth-child(' + str(i) + ') > span > a'
    content = driver.find_element_by_css_selector(css)
    all_title.append(content.text)

print(all_title)

# %% [markdown]
# ### CSS Selector
# HTML 요소를 선택해주는 요소
# - 태그 선택자
# - 클래스 선택자(.)
# - ID 선택자(#)
# - 자식 선택자(>)
# - 하위 선택자( )

# %%
# 현재 열려있는 페이지 url 찾기
url = driver.current_url
url
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-69c6ba7bfc55> in <module>()
#       1 # 현재 열려있는 페이지 url 찾기
# ----> 2 url = driver.current_url
#       3 url
#
# NameError: name 'driver' is not defined

# %%
# 브라우저 닫기
driver.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c7d8aabf870b> in <module>()
#       1 # 브라우저 닫기
# ----> 2 driver.close()
#
# NameError: name 'driver' is not defined

# %% [markdown]
# ## 크롤링 예제
#
# cine21 배우 랭킹 사이트 크롤링
#   - 사이트 주소: http://www.cine21.com/rank/person/
#   - 요청 방식 확인 방법: 크롬 개발자 모드로 들어가서, Network -> Fetch/XHR -> content 페이지의 요청 방식 확인
#     - Request URL: http://www.cine21.com/rank/person/content
#     - Request Method: POST
#     - Form data
#       - section = 'actor'
#       - period_start = '2021-07'
#       - gender = 'all'
#       - page = 1

# %%
import re
import requests
from bs4 import BeautifulSoup

# %%
cine21_url = 'http://www.cine21.com/rank/person/'
res = requests.get(cine21_url)
print(res.text) # get으로 할 경우 배우 리스트가 응답으로 반환되지 않음(사이트마다 다름)

# %% [markdown]
# ### 크롤링 주소 요청
# dictionary를 이용하여 form data 생성
# request모듈의 post 함수를 이용하여 요청 전송
#
# - 첫 번째 인자: 요청 url
# - 두 번째 인자: form data

# %%
cine21_url = 'http://www.cine21.com/rank/person/content'
post_data = dict()
post_data['section'] = 'actor'
post_data['period_start'] = '2021-07'
post_data['gender'] = 'all'
post_data['page'] = 1

res = requests.post(cine21_url, data=post_data)

# %%
res.text

# %%
soup = BeautifulSoup(res.text, 'html.parser')

# %% [markdown]
# ### 배우 이름 추출

# %%
# select(): find_all()과 동일한 작동을 하는 함수
# 차이점은 파라미터로 css selector를 사용
# 좀 더 간편하다
soup.select('li.people_li div.name') # class가 people_li인 li 태그 중 class가 name인 div 태그 list
# Out:
# []

# %%
actors = soup.select('li.people_li div.name')
for actor in actors:
    print(actor.text)

# %% [markdown]
# 이름만 추출할 수 없을까? -> 정규표현식 사용

# %%
test_data = '조우진(2편)'
# re.sub(정규 표현식, 치환 문자, 대상 문자열)
re.sub('\(\w*\)', '', test_data) # \w: 문자, 숫자와 매치
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-f24b919ac03a> in <module>()
#       1 test_data = '조우진(2편)'
#       2 # re.sub(정규 표현식, 치환 문자, 대상 문자열)
# ----> 3 re.sub('\(\w*\)', '', test_data) # \w: 문자, 숫자와 매치
#
# NameError: name 're' is not defined

# %%
actors = soup.select('li.people_li div.name')
for actor in actors:
    print(re.sub('\(\w*\)', '', actor.text))

# %% [markdown]
# ### 배우 상세 정보 추출

# %%
actors = soup.select('li.people_li div.name')
# select_one(): find()와 대응되는 함수
for actor in actors:
    print (actor.select_one('a'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-330d74acee57> in <module>()
# ----> 1 actors = soup.select('li.people_li div.name')
#       2 # select_one(): find()와 대응되는 함수
#       3 for actor in actors:
#       4     print (actor.select_one('a'))
#
# NameError: name 'soup' is not defined

# %%
actors = soup.select('li.people_li div.name')
actors_info_list = list()

for actor in actors:
    actor_link = 'http://www.cine21.com' + actor.select_one('a')['href'] # 태그 내 속성 접근
    response_actor = requests.get(actor_link) # 배우 상세 페이지 이동
    soup_actor = BeautifulSoup(response_actor.text, 'html.parser')
    default_info = soup_actor.select_one('ul.default_info')
    actor_details = default_info.select('li')
    print(actor_details)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-342cf5ce4ee7> in <module>()
# ----> 1 actors = soup.select('li.people_li div.name')
#       2 actors_info_list = list()
#       3
#       4 for actor in actors:
#       5     actor_link = 'http://www.cine21.com' + actor.select_one('a')['href'] # 태그 내 속성 접근
#
# NameError: name 'soup' is not defined

# %% [markdown]
# 배우마다 가지고 있는 정보가 다르다!
# -> dictionary 형태로 저장

# %%
actors = soup.select('li.people_li div.name')
actors_info_list = list()

for actor in actors:
    actor_link = 'http://www.cine21.com' + actor.select_one('a')['href'] # 태그 내 속성 접근
    response_actor = requests.get(actor_link) # 배우 상세 페이지 이동
    soup_actor = BeautifulSoup(response_actor.text, 'html.parser')
    default_info = soup_actor.select_one('ul.default_info')
    actor_details = default_info.select('li')
    
    actor_info_dict = dict()
    
    for actor_detail in actor_details:
        actor_detail_key = actor_detail.select_one('span.tit').text # 상세정보 key값
        actor_detail_value = re.sub('<span.*>.*</span>', '', str(actor_detail)) # span 태그 제거
        actor_detail_value = re.sub('<.*?>', '', actor_detail_value) # 상세정보 value값
        actor_info_dict[actor_detail_key] = actor_detail_value
        
    actors_info_list.append(actor_info_dict)

actors_info_list

# %% [markdown]
# ### 특수한 정규 표현식
# Greedy(.*) vs Non-Greedy(.*?)
# - . 문자는 개행 문자를 제외한 모든 문자 한개를 의미
# - \* 문자는 앞 문자가 0번 이상 반복되는 패턴
# - ? 문자는 패턴에 여러 개가 포함될 경우 가장 적은 개수만 포함되도록 함
#
# ```html
# <li><span class="tit">직업</span>배우</li>
#   - <.*> -> <li><span class="tit">원어명</span>주지훈</li>
#   - <.*?> -> <li>
# ```

# %% [markdown]
# ### 최종 코드

# %%
actors_info_list = list()
actors = soup.select('li.people_li div.name')

for index, actor in enumerate(actors):
    actor_info_dict = dict()
    actor_name = re.sub('\(\w*\)', '', actor.text)
    actor_info_dict['이름'] = actor_name
    
    actor_link = 'http://www.cine21.com' + actor.select_one('a')['href']
    response_actor = requests.get(actor_link)
    soup_actor = BeautifulSoup(response_actor.text, 'html.parser')
    default_info = soup_actor.select_one('ul.default_info')
    actor_details = default_info.select('li')
    
    for actor_detail in actor_details:
        actor_detail_key = actor_detail.select_one('span.tit').text
        actor_detail_value = re.sub('<span.*>.*</span>', '', str(actor_detail))
        actor_detail_value = re.sub('<.*?>', '', actor_detail_value)
        actor_info_dict[actor_detail_key] = actor_detail_value
        
    actors_info_list.append(actor_info_dict)

actors_info_list
# Out:
# []
